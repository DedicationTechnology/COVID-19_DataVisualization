# %%
import pandas as pd
import numpy as np
data = pd.read_csv("../day06/data/data/detail.csv", encoding= "gbk")
# 离差标准化
# def maxmin(data):
#     return ((data - data.min()) / (data.max() - data.min()))  # 离差标准化公式
# a = maxmin(data["counts"])
# b = maxmin(data["amounts"])
# pd.concat([a, b], axis = 1)  # 横向堆叠
# 标准差标准化
# def maxmin(data):
#     return ((data - data.mean()) / data.std())  # 标准差标准化公式
# a = maxmin(data["counts"])
# b = maxmin(data["amounts"])
# pd.concat([a, b], axis = 1)  # 横向堆叠
# 小数定标标准化
def maxmin(data):
    # np.ceil表示计算大于等于该值的最小整数
    return data / 10 ** (np.ceil(np.log10(data.abs().max())))  # 小数定标标准化公式
a = maxmin(data["counts"])
b = maxmin(data["amounts"])
pd.concat([a, b], axis = 1)  # 横向堆叠
# Out:
#        counts  amounts
# 0         0.1    0.049
# 1         0.1    0.048
# 2         0.1    0.030
# 3         0.1    0.025
# 4         0.1    0.013
# ...       ...      ...
# 10032     0.1    0.035
# 10033     0.1    0.036
# 10034     0.1    0.039
# 10035     0.1    0.007
# 10036     0.1    0.027
#
# [10037 rows x 2 columns]
